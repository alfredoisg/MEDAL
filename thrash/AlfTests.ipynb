# %%
import pandas as pd
from ImportAlpha import *
import numpy as np
import matplotlib.pyplot as plt
import os
from importAlf import *

pd.set_option('display.max_columns',200)
plt.style.use(['science','notebook','grid'])

# %%
df = alf_JoinAndLoad()

# %%
# impp = getSCparam(df)

# %%
compareSCmodules(df)
# Out:
# ['Voc', 'Isc', 'FF', 'Vmpp', 'Impp', 'MPP', 'Irradiance', 'irradiance_yield', 'irradiation', 'temp', 'rain', 'ambient_temperature', 'wind_direction', 'wind_speed']
