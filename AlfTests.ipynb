# %%
import pandas as pd
from ImportAlpha import *
import numpy as np
import matplotlib.pyplot as plt
import os
from importAlf import *

pd.set_option('display.max_columns',200)
plt.style.use(['science','notebook','grid'])

# %%
df = alf_JoinAndLoad()

# %%
impp = getSCparam(df)
temp = getSCparam(df)
# Out:
# ['Voc', 'Isc', 'FF', 'Vmpp', 'Impp', 'MPP', 'Irradiace', 'irradiance_yield', 'irradiation', 'temp', 'rain', 'ambient_temperature', 'wind_direction', 'wind_speed']
# ['Voc', 'Isc', 'FF', 'Vmpp', 'Impp', 'MPP', 'Irradiace', 'irradiance_yield', 'irradiation', 'temp', 'rain', 'ambient_temperature', 'wind_direction', 'wind_speed']

# %%
compareSCmodules(temp)
# Out:
# ['Voc', 'Isc', 'FF', 'Vmpp', 'Impp', 'MPP', 'Irradiace', 'irradiance_yield', 'irradiation', 'temp', 'rain', 'ambient_temperature', 'wind_direction', 'wind_speed']

# %%
# alf_2var_plotter(df)

# %%
# MS02 = select_panel(df)

# %%
# MS02

# %%
# sc = 'Impp'

# %%
# %%timeit
# df[[i for i in df.columns if sc in i]].copy()

# %%
# impp = df[[i for i in df.columns if sc in i]].copy()
# impp.insert(0,'Timestamp',df.iloc[:,0])

# %%
# df.columns

# %%
['Voc', 'Isc', 'FF', 'Vmpp', 'Impp', 'MPP',
 'Irradiace', 'irradiance_yield', 'irradiation',
 'temp','rain', 'ambient_temperature','wind_direction', 
 'wind_speed']
# Out:
# ['Voc',
#  'Isc',
#  'FF',
#  'Vmpp',
#  'Impp',
#  'MPP',
#  'Irradiace',
#  'irradiance_yield',
#  'irradiation',
#  'temp',
#  'rain',
#  'ambient_temperature',
#  'wind_direction',
#  'wind_speed']

# %%
# temp =df[[i for i in df.columns if 'temp' in i]].copy()
# temp.insert(0,'Timestamp',df.iloc[:,0])

# %%
# temp

# %%
# impp

# %%
# impp.columns[1:].tolist()

# %%
impp.plot(x='Timestamp', y=impp.columns[1:].tolist(), figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Timestamp'>

# %%
# df[[i for i in df.columns if 'yield' in i]].copy()

# %%
# df[[i for i in df.columns if 'irradiance' in i]].copy()
