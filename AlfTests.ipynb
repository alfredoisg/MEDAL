# %%
import pandas as pd
from ImportAlpha import *
import numpy as np
import matplotlib.pyplot as plt
import os
from importAlf import *

pd.set_option('display.max_columns',200)
plt.style.use(['science','notebook','grid'])

# %%
df = alf_JoinAndLoad()

# %%
df.head()
# Out:
#             Timestamp  FF MS03  FF MS05  FF MS07  FF MS08  FF MS01  FF MS02  \
# 0 2022-07-04 10:30:00     0.77     0.77     0.76     0.76     0.77     0.76
# 1 2022-07-04 10:31:00     0.76     0.76     0.76     0.77     0.77     0.76
# 2 2022-07-04 10:32:00     0.78     0.78     0.79     0.79     0.79     0.79
# 3 2022-07-04 10:33:00     0.76     0.76     0.76     0.76     0.76     0.76
# 4 2022-07-04 10:34:00     0.76     0.76     0.76     0.76     0.76     0.76
#
#    FF MS04  FF MS06  ambient humidity  Impp MS01  Impp MS02  Impp MS03  \
# 0     0.78     0.76              69.0      8.705      7.938      7.675
# 1     0.76     0.76              70.0      8.762      8.506      9.108
# 2     0.78     0.78              69.0      5.101      5.208      6.060
# 3     0.76     0.76              70.0      9.448      9.202      9.445
# 4     0.76     0.76              70.0      9.366      9.100      9.381
#
#    Impp MS04  Impp MS05  Impp MS06  Impp MS07  Impp MS08  irradiance MS01  \
# ...

# %%
alf_2var_plotter(df)
# Out:
# Index(['Timestamp', 'FF MS03', 'FF MS05', 'FF MS07', 'FF MS08', 'FF MS01',
#        'FF MS02', 'FF MS04', 'FF MS06', 'ambient humidity', 'Impp MS01',
#        'Impp MS02', 'Impp MS03', 'Impp MS04', 'Impp MS05', 'Impp MS06',
#        'Impp MS07', 'Impp MS08', 'irradiance MS01', 'irradiance MS02',
#        'irradiance MS03', 'irradiance MS04', 'irradiance MS05',
#        'irradiance MS06', 'irradiance MS07', 'irradiance MS08',
#        '¹ Calculated value', 'irradiance yield MS01', 'irradiance yield MS02',
#        'irradiance yield MS03', 'irradiance yield MS04',
#        'irradiance yield MS05', 'irradiance yield MS06',
#        'irradiance yield MS07', 'irradiance yield MS08', 'irradiation 1',
#        'irradiation 2', 'irradiation 3', 'Isc MS01', 'Isc MS02', 'Isc MS03',
#        'Isc MS04', 'Isc MS05', 'Isc MS06', 'Isc MS07', 'Isc MS08',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M2-MS01)',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M2-MS02)',
# ...

# %%
test = ['FF MS03', 'resafa']

# %%
df.columns
# Out:
# Index(['Timestamp', 'FF MS03', 'FF MS05', 'FF MS07', 'FF MS08', 'FF MS01',
#        'FF MS02', 'FF MS04', 'FF MS06', 'ambient humidity', 'Impp MS01',
#        'Impp MS02', 'Impp MS03', 'Impp MS04', 'Impp MS05', 'Impp MS06',
#        'Impp MS07', 'Impp MS08', 'irradiance MS01', 'irradiance MS02',
#        'irradiance MS03', 'irradiance MS04', 'irradiance MS05',
#        'irradiance MS06', 'irradiance MS07', 'irradiance MS08',
#        '¹ Calculated value', 'irradiance yield MS01', 'irradiance yield MS02',
#        'irradiance yield MS03', 'irradiance yield MS04',
#        'irradiance yield MS05', 'irradiance yield MS06',
#        'irradiance yield MS07', 'irradiance yield MS08', 'irradiation 1',
#        'irradiation 2', 'irradiation 3', 'Isc MS01', 'Isc MS02', 'Isc MS03',
#        'Isc MS04', 'Isc MS05', 'Isc MS06', 'Isc MS07', 'Isc MS08',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M2-MS01)',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M2-MS02)',
# ...

# %%
all(item in test for item in df.columns)
# Out:
# False
