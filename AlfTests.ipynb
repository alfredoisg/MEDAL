# %%
import pandas as pd
from ImportAlpha import *
import numpy as np
import matplotlib.pyplot as plt
import os
from importAlf import *

pd.set_option('display.max_columns',200)
plt.style.use(['science','notebook','grid'])

# %%
df = alf_JoinAndLoad()

# %%
alf_2var_plotter(df)
# Out:
# Index(['Timestamp', 'FF_MS03', 'FF_MS05', 'FF_MS07', 'FF_MS08', 'FF_MS01',
#        'FF_MS02', 'FF_MS04', 'FF_MS06', 'ambient_humidity', 'Impp_MS01',
#        'Impp_MS02', 'Impp_MS03', 'Impp_MS04', 'Impp_MS05', 'Impp_MS06',
#        'Impp_MS07', 'Impp_MS08', 'irradiance_MS01', 'irradiance_MS02',
#        'irradiance_MS03', 'irradiance_MS04', 'irradiance_MS05',
#        'irradiance_MS06', 'irradiance_MS07', 'irradiance_MS08',
#        '¹ Calculated value', 'irradiance_yield_MS01', 'irradiance_yield_MS02',
#        'irradiance_yield_MS03', 'irradiance_yield_MS04',
#        'irradiance_yield_MS05', 'irradiance_yield_MS06',
#        'irradiance_yield_MS07', 'irradiance_yield_MS08', 'irradiation_1',
#        'irradiation_2', 'irradiation_3', 'Isc_MS01', 'Isc_MS02', 'Isc_MS03',
#        'Isc_MS04', 'Isc_MS05', 'Isc_MS06', 'Isc_MS07', 'Isc_MS08',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M2-MS01)',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M2-MS02)',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M1-MS07)',
#        'MPP Yield ¹ [Wh] (Alpha Centauri - M1-MS08)', 'MPP_MS01', 'MPP_MS02',
#        'MPP_MS03', 'MPP_MS04', 'MPP_MS05', 'MPP_MS06', 'MPP_MS07', 'MPP_MS08',
#        'rain', 'ambient_temperature', 'temp_MS08', 'temp_MS07', 'temp_MS06',
#        'temp_MS05', 'temp_MS04', 'temp_MS03', 'temp_MS02', 'temp_MS01',
#        'Vmpp_MS01', 'Vmpp_MS02', 'Vmpp_MS03', 'Vmpp_MS04', 'Vmpp_MS05',
#        'Vmpp_MS06', 'Vmpp_MS07', 'Vmpp_MS08', 'Voc_MS01', 'Voc_MS02',
#        'Voc_MS03', 'Voc_MS04', 'Voc_MS05', 'Voc_MS08', 'Voc_MS07', 'Voc_MS06',
#        'wind_direction', 'wind_speed'],
#       dtype='object')

# %%
MS02 = select_panel(df)
# Out:
# ['MS01', 'MS02', 'MS03', 'MS04', 'MS05', 'MS06', 'MS07', 'MS08']
# Panel not in list
# Try again

# %%
# MS02
